# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Análisis exploratorio

# %%
# df = pd.read_csv('./train_airlines_delay_challenge.csv')
df = pd.read_csv('/content/drive/MyDrive/train_airlines_delay_challenge.csv')
print(df.shape)
df.head()
# Out:
# (9000000, 14)
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2009-09-05         AA               2062    MIA  BOS        1055.0
# 1  2009-05-08         XE               2926    IAH  ELP        2115.0
# 2  2009-03-16         OH               6433    CVG  DSM        1430.0
# 3  2009-03-04         OO               5439    LAX  SBA         820.0
# 4  2009-06-12         WN                615    LAS  MCI        1235.0
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  CRS_ARR_TIME  ARR_DELAY  \
# 0    1139.0       44.0      15.0      1154.0        1405.0       30.0
# 1    2112.0       -3.0      17.0      2129.0        2219.0      -15.0
# 2    1425.0       -5.0      25.0      1450.0        1518.0        7.0
# 3     814.0       -6.0      15.0       829.0         905.0      -11.0
# 4    1234.0       -1.0      13.0      1247.0        1735.0      -26.0
#
#    CRS_ELAPSED_TIME  DISTANCE
# 0             190.0    1258.0
# 1             124.0     667.0
# 2             108.0     505.0
# 3              45.0      89.0
# 4             180.0    1140.0

# %% [markdown]
# Se carga el dataset y observa su composición asi como el total de filas y columnas.

# %%
# Tipo de atributos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000000 entries, 0 to 8999999
# Data columns (total 14 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   FL_DATE            object
#  1   OP_CARRIER         object
#  2   OP_CARRIER_FL_NUM  int64
#  3   ORIGIN             object
#  4   DEST               object
#  5   CRS_DEP_TIME       float64
#  6   DEP_TIME           float64
#  7   DEP_DELAY          float64
#  8   TAXI_OUT           float64
#  9   WHEELS_OFF         float64
#  10  CRS_ARR_TIME       float64
#  11  ARR_DELAY          float64
#  12  CRS_ELAPSED_TIME   float64
#  13  DISTANCE           float64
# dtypes: float64(9), int64(1), object(4)
# memory usage: 961.3+ MB

# %% [markdown]
# ## Descripción de los atributos
#
# - **`FL_DATE`**: Fecha de vuelo
# - **`OP_CARRIER`**: Identificador de la aerolínea
# - **`OP_CARRIER_FL_NUM`**: Número de vuelo
# - **`ORIGIN`**: Código del aeropuerto de origen
# - **`DEST`**: Código del aeropuerto de destino
# - **`CRS_DEP_TIME`**: Hora planeada de salida
# - **`DEP_TIME`**: Hora actual de salida
# - **`DEP_DELAY`**: Retraso en la salida (en minutos)
# - **`TAXI_OUT`**: El tiempo transcurrido entre la salida desde el aeropuerto de origen y el atributo "WHEELS_OFF"
# - **`WHEELS_OFF`**: Hora a la que las llantas del avión dejaron de tocar el suelo
# - **`CRS_ARR_TIME`**: Hora planeada de llegada
# - **`ARR_DELAY`**: Retraso total en la llegada en minutos (atributo a predecir)
# - **`CRS_ELAPSED_TIME`**: Tiempo total planeado del vuelo
# - **`DISNTANCE`**: Distancia entre los dos aeropuertos

# %%
# Revisar valores nulos
df.isnull().sum()
# Out:
# FL_DATE              0
# OP_CARRIER           0
# OP_CARRIER_FL_NUM    0
# ORIGIN               0
# DEST                 0
# CRS_DEP_TIME         0
# DEP_TIME             0
# DEP_DELAY            0
# TAXI_OUT             0
# WHEELS_OFF           0
# CRS_ARR_TIME         0
# ARR_DELAY            0
# CRS_ELAPSED_TIME     0
# DISTANCE             0
# dtype: int64

# %%
df['OP_CARRIER'].unique() # Todos los identificadores de aerolíneas
# Out:
# array(['AA', 'XE', 'OH', 'OO', 'WN', 'EV', 'YV', 'NW', 'UA', 'MQ', 'F9',
#        'US', 'FL', 'CO', 'AS', 'DL', 'B6', 'HA', '9E', 'VX', 'NK'],
#       dtype=object)

# %% [markdown]
# ### Identificador y Aerolínea
# | Código | Aerolínea |
# | ------ | ---------- |
# | **AA** | *American Airlines* |
# | **AS** | *Alaska Airlines* |
# | **B6** | *JetBlue Airways* |
# | **CO** | *Continental Airlines (ahora parte de United Airlines)* |
# | **DL** | *Delta Air Lines* |
# | **EV** | *Envoy Air (operando como American Eagle)* |
# | **FL** | *AirTran Airways (ahora parte de Southwest Airlines)* |
# | **F9** | *Frontier Airlines* |
# | **HA** | *Hawaiian Airlines* |
# | **MQ** | *Envoy Air (operando como American Eagle)* |
# | **NK** | *Spirit Airlines* |
# | **NW** | *Northwest Airlines (ahora parte de Delta Air Lines)* |
# | **OO** | *SkyWest Airlines* |
# | **OH** | *PSA Airlines (operando como American Eagle)* |
# | **UA** | *United Airlines* |
# | **US** | *US Airways (ahora parte de American Airlines)* |
# | **VX** | *Virgin America (ahora parte de Alaska Airlines)* |
# | **WN** | *Southwest Airlines* |
# | **XE** | *ExpressJet Airlines* |
# | **YV** | *Mesa Airlines* |
# | **9E** | *Pinnacle Airlines* |

# %%
# Revisando duplicados
dup_total = df.duplicated().sum()
if dup_total > 0:
    print(dup_total) # Total de duplicados
    # Mostrar los primeros 5 duplicados
    dup = df[df.duplicated()]
    print(dup.head())
# Out:
# 27522
#           FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 932    2009-09-09         WN                635    PHX  CMH         945.0
# 13937  2009-09-04         OO               4716    SLC  GTF        1056.0
# 16722  2009-09-26         FL                129    TPA  ATL        1840.0
# 24106  2009-09-09         MQ               4631    RDU  DCA        1200.0
# 25345  2009-09-19         9E               3846    FWA  DTW         645.0
#
#        DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  CRS_ARR_TIME  ARR_DELAY  \
# 932       954.0        9.0       8.0      1002.0        1625.0        6.0
# 13937    1059.0        3.0       8.0      1107.0        1225.0       -7.0
# 16722    1845.0        5.0      88.0      2013.0        2010.0       78.0
# 24106    1153.0       -7.0      12.0      1205.0        1300.0       -8.0
# 25345     638.0       -7.0      21.0       659.0         745.0       -9.0
#
#        CRS_ELAPSED_TIME  DISTANCE
# 932               220.0    1671.0
# 13937              89.0     463.0
# 16722              90.0     406.0
# 24106              60.0     227.0
# 25345              60.0     128.0

# %% [markdown]
# Como se puede apreciar existen valores duplicados en el dataframe siendo un total de 27,522.

# %% [markdown]
# # Limpieza de datos

# %% [markdown]
# ## Eliminando los duplicados
# Se eliminan los duplicados y se revisa que así sea.

# %%
df = df.drop_duplicates() # Elimiando los valores duplicados

# %%
print(df.duplicated().sum()) # Revisando nuevamente por valores duplicados
# Out:
# 0

# %% [markdown]
# ### ¿Cúales son los datos de vuelo con retraso?
# - **Si en `ARR_DELAY` es positivo quiere decir que llegó con retraso el avión**
# - **Si en `DEP_DELAY` es positivo quiere decir que salió con retrso el avión**

# %%
# Retraso en la llegada (min)
df[df['ARR_DELAY'] > 0]
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2009-09-05         AA               2062    MIA  BOS        1055.0
# 2        2009-03-16         OH               6433    CVG  DSM        1430.0
# 6        2009-06-04         EV               5421    FAY  ATL        1633.0
# 13       2009-09-18         UA                402    MCI  ORD        1450.0
# 14       2009-02-02         YV               7070    ORD  GSP        1813.0
# ...             ...        ...                ...    ...  ...           ...
# 8999982  2017-10-25         AA               1867    CLT  BNA        2019.0
# 8999987  2017-08-17         WN               1186    BOI  DEN        1510.0
# 8999994  2017-07-18         AA               2433    MCO  DFW        1735.0
# 8999996  2017-01-06         OO               4482    SEA  SMF        2105.0
# 8999997  2017-09-24         WN               3997    DEN  SNA        1400.0
#
#          DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  CRS_ARR_TIME  ARR_DELAY  \
# 0          1139.0       44.0      15.0      1154.0        1405.0       30.0
# 2          1425.0       -5.0      25.0      1450.0        1518.0        7.0
# 6          1653.0       20.0       8.0      1701.0        1754.0       38.0
# 13         1446.0       -4.0      22.0      1508.0        1615.0        4.0
# 14         1807.0       -6.0      21.0      1828.0        2100.0        1.0
# ...           ...        ...       ...         ...           ...        ...
# 8999982    2012.0       -7.0      23.0      2035.0        2039.0        4.0
# 8999987    1630.0       80.0      13.0      1643.0        1655.0       76.0
# 8999994    1947.0      132.0      14.0      2001.0        1925.0      116.0
# 8999996    2113.0        8.0      23.0      2136.0        2306.0        7.0
# 8999997    1436.0       36.0      11.0      1447.0        1520.0       33.0
#
#          CRS_ELAPSED_TIME  DISTANCE
# 0                   190.0    1258.0
# 2                   108.0     505.0
# 6                    81.0     331.0
# 13                   85.0     403.0
# 14                  107.0     577.0
# ...                   ...       ...
# 8999982              80.0     328.0
# 8999987             105.0     649.0
# 8999994             170.0     985.0
# 8999996             121.0     605.0
# 8999997             140.0     846.0
#
# [3366065 rows x 14 columns]

# %%
# Retraso en la salida (min)
df[df['DEP_DELAY'] > 0]
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2009-09-05         AA               2062    MIA  BOS        1055.0
# 5        2009-08-04         WN                 94    OAK  PHX         600.0
# 6        2009-06-04         EV               5421    FAY  ATL        1633.0
# 10       2009-09-03         NW               1717    JFK  MSP        1955.0
# 12       2009-06-23         MQ               4060    ORD  FNT        2105.0
# ...             ...        ...                ...    ...  ...           ...
# 8999987  2017-08-17         WN               1186    BOI  DEN        1510.0
# 8999994  2017-07-18         AA               2433    MCO  DFW        1735.0
# 8999996  2017-01-06         OO               4482    SEA  SMF        2105.0
# 8999997  2017-09-24         WN               3997    DEN  SNA        1400.0
# 8999999  2017-04-17         AA                590    SMF  PHX        1620.0
#
#          DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  CRS_ARR_TIME  ARR_DELAY  \
# 0          1139.0       44.0      15.0      1154.0        1405.0       30.0
# 5           603.0        3.0       9.0       612.0         805.0       -8.0
# 6          1653.0       20.0       8.0      1701.0        1754.0       38.0
# 10         2002.0        7.0      25.0      2027.0        2233.0      -44.0
# 12         2106.0        1.0      19.0      2125.0        2305.0        0.0
# ...           ...        ...       ...         ...           ...        ...
# 8999987    1630.0       80.0      13.0      1643.0        1655.0       76.0
# 8999994    1947.0      132.0      14.0      2001.0        1925.0      116.0
# 8999996    2113.0        8.0      23.0      2136.0        2306.0        7.0
# 8999997    1436.0       36.0      11.0      1447.0        1520.0       33.0
# 8999999    1621.0        1.0      17.0      1638.0        1808.0       -1.0
#
#          CRS_ELAPSED_TIME  DISTANCE
# 0                   190.0    1258.0
# 5                   125.0     646.0
# 6                    81.0     331.0
# 10                  218.0    1028.0
# 12                   60.0     223.0
# ...                   ...       ...
# 8999987             105.0     649.0
# 8999994             170.0     985.0
# 8999996             121.0     605.0
# 8999997             140.0     846.0
# 8999999             108.0     647.0
#
# [3321460 rows x 14 columns]

# %%
# Retraso en la salida y en la llegada
df[(df['DEP_DELAY'] > 0) & (df['ARR_DELAY'] > 0)]
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2009-09-05         AA               2062    MIA  BOS        1055.0
# 6        2009-06-04         EV               5421    FAY  ATL        1633.0
# 18       2009-12-05         YV               2967    EWR  CLT        1825.0
# 21       2009-06-17         WN                867    LAS  SAN        1445.0
# 25       2009-09-02         CO                438    EWR  MIA        1055.0
# ...             ...        ...                ...    ...  ...           ...
# 8999981  2017-06-04         WN               4310    MCI  DAL         730.0
# 8999987  2017-08-17         WN               1186    BOI  DEN        1510.0
# 8999994  2017-07-18         AA               2433    MCO  DFW        1735.0
# 8999996  2017-01-06         OO               4482    SEA  SMF        2105.0
# 8999997  2017-09-24         WN               3997    DEN  SNA        1400.0
#
#          DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  CRS_ARR_TIME  ARR_DELAY  \
# 0          1139.0       44.0      15.0      1154.0        1405.0       30.0
# 6          1653.0       20.0       8.0      1701.0        1754.0       38.0
# 18         1935.0       70.0      65.0      2040.0        2027.0      103.0
# 21         1517.0       32.0      18.0      1535.0        1550.0       30.0
# 25         1100.0        5.0      19.0      1119.0        1354.0       21.0
# ...           ...        ...       ...         ...           ...        ...
# 8999981     740.0       10.0      11.0       751.0         900.0        6.0
# 8999987    1630.0       80.0      13.0      1643.0        1655.0       76.0
# 8999994    1947.0      132.0      14.0      2001.0        1925.0      116.0
# 8999996    2113.0        8.0      23.0      2136.0        2306.0        7.0
# 8999997    1436.0       36.0      11.0      1447.0        1520.0       33.0
#
#          CRS_ELAPSED_TIME  DISTANCE
# 0                   190.0    1258.0
# 6                    81.0     331.0
# 18                  122.0     529.0
# 21                   65.0     258.0
# 25                  179.0    1086.0
# ...                   ...       ...
# 8999981              90.0     460.0
# 8999987             105.0     649.0
# 8999994             170.0     985.0
# 8999996             121.0     605.0
# 8999997             140.0     846.0
#
# [2394384 rows x 14 columns]

# %% [markdown]
# **El atributo de `DEP_DELAY` nos dice si salió con retraso el avión pero esto no es contundente para decir que el avión llegará al destino con retraso:**
# - El avión puede salir con retraso y llegar en tiempo a su destino

# %% [markdown]
# # Procesamiento de datos

# %%
df_1 = df.copy()
# Cambiando la columna ARR_DELAY a categorica
df_1['ARR_DELAY'] = df_1['ARR_DELAY'].apply(lambda x: 'delay' if x > 15
                                          else 'on time' if -15 <= x <= 15
                                          else 'early' if x < -15 else 'unknown')

# %% [markdown]
# Se tienen 3 categorias para `ARR_DELAY`:
# 1) **early** si el avión llega más de 15 minutos antes de la hora planeada de llegada.
# 2) **on time** si el avión llega dentro de ±15 minutos de la hora planeada de llegada.
# 3) **delay** si el avión llega más de 15 minutos después de la hora planeada de llegada.

# %%
df_1.head()
# Out:
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2009-09-05         AA               2062    MIA  BOS        1055.0
# 1  2009-05-08         XE               2926    IAH  ELP        2115.0
# 2  2009-03-16         OH               6433    CVG  DSM        1430.0
# 3  2009-03-04         OO               5439    LAX  SBA         820.0
# 4  2009-06-12         WN                615    LAS  MCI        1235.0
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  CRS_ARR_TIME ARR_DELAY  \
# 0    1139.0       44.0      15.0      1154.0        1405.0     delay
# 1    2112.0       -3.0      17.0      2129.0        2219.0   on time
# 2    1425.0       -5.0      25.0      1450.0        1518.0   on time
# 3     814.0       -6.0      15.0       829.0         905.0   on time
# 4    1234.0       -1.0      13.0      1247.0        1735.0     early
#
#    CRS_ELAPSED_TIME  DISTANCE
# 0             190.0    1258.0
# 1             124.0     667.0
# 2             108.0     505.0
# 3              45.0      89.0
# 4             180.0    1140.0

# %%
# Revisando que no se tengan unknowns en el dataframe
has_unknown = df_1['ARR_DELAY'].isin(['unknown']).any()

print("¿Hay algún 'unknown' en ARR_DELAY?", has_unknown)
# Out:
# ¿Hay algún 'unknown' en ARR_DELAY? False

# %% [markdown]
# ### Visualizando los retrasos de vuelos por compañia

# %%
# Cambiando el código de la aerolínea por su nombre para una mejor visualización gráfica.
df_2 = df_1.copy()

air_lines = {
    'AA': 'American Airlines',
    'AS': 'Alaska Airlines',
    'B6': 'JetBlue Airways',
    'CO': 'Continental Airlines',
    'DL': 'Delta Air Lines',
    'EV': 'Envoy Air',
    'F9': 'Frontier Airlines',
    'FL': 'AirTran Airways',
    'HA': 'Hawaiian Airlines',
    'MQ': 'Envoy Air',
    'NK': 'Spirit Airlines',
    'NW': 'Northwest Airlines',
    'OO': 'SkyWest Airlines',
    'OH': 'PSA Airlines',
    'UA': 'United Airlines',
    'US': 'US Airways',
    'VX': 'Virgin America',
    'WN': 'Southwest Airlines',
    'XE': 'ExpressJet Airlines',
    'YV': 'Mesa Airlines',
    '9E': 'Pinnacle Airlines'
}

# Cambiando los codigos a nombre para una mejor representacion grafica
df_2['OP_CARRIER'] = df_2['OP_CARRIER'].replace(air_lines)

# %%
# Contar los retrasos por compañía
delay_counts = df_2[df_2['ARR_DELAY'] == 'delay']['OP_CARRIER'].value_counts()

# %%
plt.figure(figsize=(10, 6))
delay_counts.plot(kind='bar')
plt.title('Cantidad de vuelos en retraso por compañía')
plt.xlabel('Compañía aérea')
plt.ylabel('Número de vuelos en retraso')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ahora se visualizan los retrasos en vuelos por semana, mes y año

# %%
df_3 = df_2.copy()

df_3['FLY_WEEK'] = pd.to_datetime(df_3['FL_DATE']).dt.dayofweek
df_3['FLY_MONTH'] = pd.to_datetime(df_3['FL_DATE']).dt.month
df_3['FLY_YEAR'] = pd.to_datetime(df_3['FL_DATE']).dt.year

# %%
df_3.head()
# Out:
#       FL_DATE           OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  \
# 0  2009-09-05    American Airlines               2062    MIA  BOS
# 1  2009-05-08  ExpressJet Airlines               2926    IAH  ELP
# 2  2009-03-16         PSA Airlines               6433    CVG  DSM
# 3  2009-03-04     SkyWest Airlines               5439    LAX  SBA
# 4  2009-06-12   Southwest Airlines                615    LAS  MCI
#
#    CRS_DEP_TIME  DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  CRS_ARR_TIME  \
# 0        1055.0    1139.0       44.0      15.0      1154.0        1405.0
# 1        2115.0    2112.0       -3.0      17.0      2129.0        2219.0
# 2        1430.0    1425.0       -5.0      25.0      1450.0        1518.0
# 3         820.0     814.0       -6.0      15.0       829.0         905.0
# 4        1235.0    1234.0       -1.0      13.0      1247.0        1735.0
#
#   ARR_DELAY  CRS_ELAPSED_TIME  DISTANCE  FLY_WEEK  FLY_MONTH  FLY_YEAR
# 0     delay             190.0    1258.0         5          9      2009
# 1   on time             124.0     667.0         4          5      2009
# 2   on time             108.0     505.0         0          3      2009
# 3   on time              45.0      89.0         2          3      2009
# 4     early             180.0    1140.0         4          6      2009

# %%
# Contar los retrasos por días de la semana
delay_counts_month = df_3[df_3['ARR_DELAY'] == 'delay']['FLY_WEEK'].value_counts()

# %%
plt.figure(figsize=(10, 6))
delay_counts_month.plot(kind='bar')
plt.title('Cantidad de vuelos en retraso por día')
plt.xlabel('Día')
plt.ylabel('Número de vuelos en retraso')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Contar los retrasos por mes
delay_counts_month = df_3[df_3['ARR_DELAY'] == 'delay']['FLY_MONTH'].value_counts()

# %%
plt.figure(figsize=(10, 6))
delay_counts_month.plot(kind='bar')
plt.title('Cantidad de vuelos en retraso por mes')
plt.xlabel('Mes')
plt.ylabel('Número de vuelos en retraso')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
delay_counts_year = df_3[df_3['ARR_DELAY'] == 'delay']['FLY_YEAR'].value_counts()

# %%
plt.figure(figsize=(10, 6))
delay_counts_year.plot(kind='bar')
plt.title('Cantidad de vuelos en retraso por año')
plt.xlabel('Año')
plt.ylabel('Número de vuelos en retraso')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
df_3.head()
# Out:
#       FL_DATE           OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  \
# 0  2009-09-05    American Airlines               2062    MIA  BOS
# 1  2009-05-08  ExpressJet Airlines               2926    IAH  ELP
# 2  2009-03-16         PSA Airlines               6433    CVG  DSM
# 3  2009-03-04     SkyWest Airlines               5439    LAX  SBA
# 4  2009-06-12   Southwest Airlines                615    LAS  MCI
#
#    CRS_DEP_TIME  DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  CRS_ARR_TIME  \
# 0        1055.0    1139.0       44.0      15.0      1154.0        1405.0
# 1        2115.0    2112.0       -3.0      17.0      2129.0        2219.0
# 2        1430.0    1425.0       -5.0      25.0      1450.0        1518.0
# 3         820.0     814.0       -6.0      15.0       829.0         905.0
# 4        1235.0    1234.0       -1.0      13.0      1247.0        1735.0
#
#   ARR_DELAY  CRS_ELAPSED_TIME  DISTANCE  FLY_WEEK  FLY_MONTH  FLY_YEAR
# 0     delay             190.0    1258.0         5          9      2009
# 1   on time             124.0     667.0         4          5      2009
# 2   on time             108.0     505.0         0          3      2009
# 3   on time              45.0      89.0         2          3      2009
# 4     early             180.0    1140.0         4          6      2009

# %%
df_3['REAL_FLY_TIME'] = (df_3['WHEELS_OFF'] - df_3['DEP_TIME']) / 60
df_3['DIF_TIME'] = df_3['CRS_ELAPSED_TIME'] - df_3['REAL_FLY_TIME']
df_3['ARR_TOTAL'] = df_3.groupby(['ORIGIN', 'DEST'])['DEP_DELAY'].cumsum()

# Calcular la velocidad promedio
df_3['MD_SPEED'] = df_3['DISTANCE'] / df_3['REAL_FLY_TIME']

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df_4 = df_3.copy()

for col in df_4.select_dtypes(include=['object']).columns:
    df_4[col] = label_encoder.fit_transform(df_4[col])

# %%
df_4.head()
# Out:
#    FL_DATE  OP_CARRIER  OP_CARRIER_FL_NUM  ORIGIN  DEST  CRS_DEP_TIME  \
# 0      247           2               2062     220    42        1055.0
# 1      127           6               2926     162   108        2115.0
# 2       74          12               6433      84   100        1430.0
# 3       62          14               5439     190   295         820.0
# 4      162          15                615     188   209        1235.0
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  ARR_DELAY  \
# 0    1139.0       44.0      15.0      1154.0  ...          0
# 1    2112.0       -3.0      17.0      2129.0  ...          2
# 2    1425.0       -5.0      25.0      1450.0  ...          2
# 3     814.0       -6.0      15.0       829.0  ...          2
# 4    1234.0       -1.0      13.0      1247.0  ...          1
#
#    CRS_ELAPSED_TIME  DISTANCE  FLY_WEEK  FLY_MONTH  FLY_YEAR  REAL_FLY_TIME  \
# 0             190.0    1258.0         5          9      2009       0.250000
# 1             124.0     667.0         4          5      2009       0.283333
# 2             108.0     505.0         0          3      2009       0.416667
# 3              45.0      89.0         2          3      2009       0.250000
# 4             180.0    1140.0         4          6      2009       0.216667
#
#      DIF_TIME  ARR_TOTAL     MD_SPEED
# 0  189.750000       44.0  5032.000000
# 1  123.716667       -3.0  2354.117647
# 2  107.583333       -5.0  1212.000000
# 3   44.750000       -6.0   356.000000
# 4  179.783333       -1.0  5261.538462
#
# [5 rows x 21 columns]

# %%
# Al obtener las caracteristicas de el retraso por año mes y día ya no se necesita el atributo FL_DATE
df_4 = df_4.drop('FL_DATE', axis=1)
# Se quita el año de vuelo ya que los años no se repiten pero los días y meses si. (Cada año es diferente pero los meses son los mismos al igual que los días)
df_4 = df_4.drop('FLY_YEAR', axis=1)

df_4 = df_4.drop('WHEELS_OFF', axis=1)
df_4 = df_4.drop('DEP_TIME', axis=1)
df_4 = df_4.drop('CRS_ELAPSED_TIME',axis=1)

# %%
#Sacar las categoricas de cada uno de los df siguientes
cor = df_4.corr(numeric_only=True)

plt.figure(figsize=(20, 8))
sns.heatmap(cor, annot = True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder

df_7 = df_2.copy()

label_encoder = LabelEncoder()

df_7['FLY_WEEK'] = pd.to_datetime(df_3['FL_DATE']).dt.dayofweek
df_7['FLY_MONTH'] = pd.to_datetime(df_3['FL_DATE']).dt.month

df_7['ARR_DELAY'] = df_7['ARR_DELAY'].apply(lambda x: 1 if x == 'delay'
                                          else 2 if x == 'on time'
                                          else 3 if x == 'early' else -1)

df_7['ORIGIN'] = label_encoder.fit_transform(df_2['ORIGIN'])
df_7['OP_CARRIER'] = label_encoder.fit_transform(df_2['OP_CARRIER'])

df_7 = df_7.drop('FL_DATE',axis=1)
df_7 = df_7.drop('DEST',axis=1)
df_7 = df_7.drop('OP_CARRIER_FL_NUM', axis=1)

# %%
cat_col_7 = [col for col in df_7.columns if df_7[col].dtype == 'object']
print(cat_col_7)
# Out:
# []

# %%
cor = df_7.corr(numeric_only=True)

plt.figure(figsize=(20, 8))
sns.heatmap(cor, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # Reducción de dimensionalidad

# %%
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# %%
X_7 = df_7.drop('ARR_DELAY', axis=1)
y_7 = df_7['ARR_DELAY']

# %%
X_PCA = PCA(n_components=2).fit_transform(X_7) # 158seg

scatter = plt.scatter(X_PCA[:,0], X_PCA[:,1], c=y_7)
plt.title('PCA')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.show()

# %%
X_LDA = LDA(n_components=2).fit_transform(X_7,y_7) #195

scatter = plt.scatter(X_LDA[:,0], X_LDA[:,1], c=y_7)
plt.title('LDA')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend(*scatter.legend_elements())
plt.show()

# %% [markdown]
# # Selección de características

# %%
from sklearn.feature_selection import mutual_info_classif

### Applying feature selection method
X_new = mutual_info_classif(X_LDA,y_7)

# plot feature selection
feat_imp = pd.Series(X_new, index=df_7.columns[:len(X_new)])
feat_imp.plot(kind='barh')
plt.show()

# %% [markdown]
# # Modelos de clasificación

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LinearRegression, Ridge, Lasso, LogisticRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
# Crear un DataFrame con los resultados de LDA
lda_df = pd.DataFrame(X_LDA)
lda_df['ARR_DELAY'] = y_7

# Mostrar las primeras filas del resultado
lda_df.head()
# Out:
#           0         1  ARR_DELAY
# 0 -0.980974  0.539852        1.0
# 1  0.112198  0.045705        2.0
# 2 -0.112770 -0.520233        2.0
# 3  0.418758 -1.268007        2.0
# 4  0.518009  0.338293        3.0

# %%
# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

X_train, X_test, y_train, y_test = train_test_split(X_LDA, y_7, test_size=0.2, random_state=42)

# %%
reg = LinearRegression().fit(X_train, y_train)
print(reg.score(X_train, y_train))
# Out:
# 0.3454618969588523

# %%
y_pred_LG = reg.predict(X_train)

# %%
import matplotlib as mpl

mpl.rcParams['agg.path.chunksize'] = 1000
mpl.rcParams['path.simplify_threshold'] = 0.01

# Plot the regression line with actual data pointa
plt.plot(X_train, y_train, '+', label='Actual values')
plt.plot(X_train, y_pred_LG, label='Predicted values')
plt.xlabel('Test input')
plt.ylabel('Test Output or Predicted output')
plt.legend()
plt.show()

# %%
import numpy as np
# Function to evaluate models and plot predictions
def evaluate_model(model, X_train, X_test, y_train, y_test, model_name):
    model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)

    print(f'Model: {model_name}')
    print(f'Train R^2: {r2_score(y_train, y_pred_train):.4f}')
    print(f'Test R^2: {r2_score(y_test, y_pred_test):.4f}')
    print(f'Test RMSE: {np.sqrt(mean_squared_error(y_test, y_pred_test)):.4f}')
    print('-'*40)

    # Plot the predictions vs real values
    plt.figure(figsize=(4, 4))
    plt.scatter(y_test, y_pred_test, label='Predictions', color='blue')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title(f'Actual vs Predicted - {model_name}')
    plt.legend()
    plt.show()

# %%
# 1. Linear Regression
linear_reg = LinearRegression()
evaluate_model(linear_reg, X_train, X_test, y_train, y_test, 'Linear Regression')

# 2. Ridge Regression
ridge_reg = Ridge(alpha=1.0)
evaluate_model(ridge_reg, X_train, X_test, y_train, y_test, 'Ridge Regression')

# 3. Lasso Regression
lasso_reg = Lasso(alpha=0.1)
evaluate_model(lasso_reg, X_train, X_test, y_train, y_test, 'Lasso Regression')
# Out:
# Model: Linear Regression
# Train R^2: 0.3455
# Test R^2: 0.3442
# Test RMSE: 0.4856
# ----------------------------------------
# Model: Ridge Regression
# Train R^2: 0.3455
# Test R^2: 0.3442
# Test RMSE: 0.4856
# ----------------------------------------
# Model: Lasso Regression
# Train R^2: 0.3147
# Test R^2: 0.3139
# Test RMSE: 0.4967
# ----------------------------------------

# %%
from sklearn import tree, metrics

dt_clf_1 = DecisionTreeClassifier(max_depth=5).fit(X_train, y_train)

y_pred_df_1 = dt_clf_1.predict(X_test)

# Accuracy
print("Accuracy: ", metrics.accuracy_score(y_test, y_pred_df_1)) #0.7681
# Out:
# Accuracy:  0.7681789204322551

# %%
# Construir modelo con datos de training
clf_gnb = GaussianNB().fit(X_train, y_train)

# Evaluar modelo con datos de testing
score = clf_gnb.score(X_test, y_test)
print("Score: ", score)

y_pred_gnb = clf_gnb.predict(X_test)

# Accuracy
print("Accuracy: ", metrics.accuracy_score(y_test, y_pred_gnb)) # 0.7528
# Out:
# Score:  0.7528916197082635
# Accuracy:  0.7528916197082635

# %%
knn = KNeighborsClassifier(n_neighbors=2)
clf_knn = knn.fit(X_train, y_train)

y_pred_knn = clf_knn.predict(X_test)

# Accuracy
print("Accuracy: ", metrics.accuracy_score(y_test, y_pred_knn)) #0.7060
# Out:
# Accuracy:  0.706041696387175

# %%
from sklearn import tree, metrics

dt_clf = DecisionTreeClassifier(criterion="entropy", max_depth=5).fit(X_train, y_train)

y_pred_df = dt_clf.predict(X_test)

# Accuracy
print("Accuracy: ", metrics.accuracy_score(y_test, y_pred_df)) #0.7687
# Out:
# Accuracy:  0.7687033016512714

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

hgc_clf = HistGradientBoostingClassifier(max_depth=4).fit(X_train, y_train)

y_pred_hgc = hgc_clf.predict(X_test)

# Accuracy
print("Accuracy: ", metrics.accuracy_score(y_test, y_pred_hgc)) # 0.7698
# Out:
# Accuracy:  0.769886920895895

# %%
from sklearn.ensemble import AdaBoostClassifier

abc_clf = AdaBoostClassifier().fit(X_train, y_train)

y_pred_abc = abc_clf.predict(X_test)

# Accuracy
print("Accuracy: ", metrics.accuracy_score(y_test, y_pred_abc)) # 0.7667
# Out:
# Accuracy:  0.7667662675202397

# %%
svc_clf = SVC().fit(X_train, y_train)

y_pred_svc = svc_clf.predict(X_test)

# Accuracy
print("Accuracy: ", metrics.accuracy_score(y_test, y_pred_svc)) # 0.7

# %%
import joblib

joblib.dump(hgc_clf, 'hgc_clf.pkl')  # Guarda el modelo en un archivo

joblib.dump(dt_clf, 'dt_clf.pkl')  # Guarda el modelo en un archivo

joblib.dump(abc_clf, 'abc_clf.pkl')  # Guarda el modelo en un archivo

joblib.dump(svc_clf, 'svc_clf.pkl')  # Guarda el modelo en un archivo
# Out:
# ['abc_clf.pkl']

# %%
joblib.dump(svc_clf, 'svc_clf.pkl')  # Guarda el modelo en un archivo
